# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
from IPython.display import HTML
# %load_ext autoreload
# %reload_ext autoreload

# %%
from simulation import *

# %%
autoreload(simulation)

# %%
plt.close('all')

debugMode = False

simulation = Simulation(TestBus, show=not debugMode, iterations=50, interval=100, debug=debugMode)

HTML(simulation.anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-257ae3752c72> in <module>()
#       5 simulation = Simulation(TestBus, show=not debugMode, iterations=50, interval=100, debug=debugMode)
#       6
# ----> 7 HTML(simulation.anim.to_html5_video())
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/animation.py in to_html5_video(self)
#     981                                 bitrate=rcParams['animation.bitrate'],
#     982                                 fps=1000. / self._interval)
# --> 983                 self.save(f.name, writer=writer)
#     984
#     985             # Now open and base64 encode
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     836                         # TODO: See if turning off blit is really necessary
#     837                         anim._draw_next_frame(d, blit=False)
# --> 838                     writer.grab_frame(**savefig_kwargs)
#     839
#     840         # Reconnect signal for first draw if necessary
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     234             # frame format and dpi.
#     235             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 236                              dpi=self.dpi, **savefig_kwargs)
#     237         except (RuntimeError, IOError) as e:
#     238             out, err = self._proc.communicate()
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1561             self.set_frameon(frameon)
#    1562
# -> 1563         self.canvas.print_figure(*args, **kwargs)
#    1564
#    1565         if frameon:
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     506
#     507     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 508         FigureCanvasAgg.draw(self)
#     509         renderer = self.get_renderer()
#     510         original_dpi = renderer.dpi
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2317
#    2318         for zorder, a in dsu:
# -> 2319             a.draw(renderer)
#    2320
#    2321         renderer.close_group('axes')
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#    2340         # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    2341         # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
# -> 2342         Text.draw(self, renderer)
#    2343
#    2344     def get_window_extent(self, renderer=None):
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     747
#     748         with _wrap_text(self) as textobj:
# --> 749             bbox, info, descent = textobj._get_layout(renderer)
#     750             trans = textobj.get_transform()
#     751
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     404
#     405         # now rotate the bbox
# --> 406         cornersRotated = M.transform(cornersHoriz)
#     407
#     408         txs = cornersRotated[:, 0]
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/transforms.py in transform(self, values)
#    1660
#    1661     def transform(self, values):
# -> 1662         return self.transform_affine(values)
#    1663     transform.__doc__ = Transform.transform.__doc__
#    1664
#
# /home/marco/.local/lib/python3.5/site-packages/matplotlib/transforms.py in transform_affine(self, points)
#    1744             tpoints = affine_transform(points.data, mtx)
#    1745             return ma.MaskedArray(tpoints, mask=ma.getmask(points))
# -> 1746         return affine_transform(points, mtx)
#    1747
#    1748     def transform_point(self, point):
#
# KeyboardInterrupt:
