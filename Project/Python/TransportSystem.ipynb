# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
from IPython.display import HTML
from simulation import *

# %%
plt.close('all')

debugMode = False


simulation = Simulation(TestBus, show=not debugMode, iterations=100, interval=100, debug=debugMode)

HTML(simulation.anim.to_html5_video())
# Out:
# <video width="800.0" height="600.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df = pd.read_pickle('./passengers.dataframe')
df['Time'] = pd.to_datetime(df['Time'], format="%H:%M")
stations = df.columns[2:]

# %%
[3,16,11,1,19,23,13,10,4,3]
[3,4,5,17,7,1,23,14,0,22,21,20,3]
[3,9,8,6,8,2,8,9,3]
[3,9,20,12,15,18,15,0,22,21,20,3]
